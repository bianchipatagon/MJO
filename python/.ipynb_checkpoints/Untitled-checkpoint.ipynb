# %%
import pandas as pd

# %%
df = pd.read_fwf('../datos/mjo/fmo.1x.txt', widths=[4, 3, 3, 3, 12, 12, 12],
                 names=['iyear', 'imonth', 'iday', 'ihour', 'PC1_coefficient', 'PC2_coefficient', 'PC1_PC2_amplitude'])
df['datetime'] = pd.to_datetime({
    'year': df['iyear'],
    'month': df['imonth'], 
    'day': df['iday'],
    'hour': df['ihour']
})
df.set_index('datetime', inplace=True)
df.drop(['iyear', 'imonth', 'iday', 'ihour'], axis=1, inplace=True)

# %%
def determinar_fase(omi1, omi2):
    """
    Ejemplo de lógica completa (debes adaptar los valores umbral)
    """
    x=omi2
    y=-omi1
    if x>0:
        if y>0:
            if x>y:
                return 5
            else:
                return 6
        else:
            if x>y:
                return 4
            else:
                return 3
    else:
        if y>0:
            if x>y:
                return 7
            else:
                return 8
        else:
            if x>y:
                return 2
            else:
                return 1

# %%
df['fase']=df.apply(lambda row: determinar_fase(row['PC1_coefficient'], row['PC2_coefficient']), axis=1)

# %%
df['fase'].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
df2=pd.read_csv('../datos/mjo/WH.txt',header=None)


df2['datetime'] = pd.to_datetime({
    'year': df2[0],
    'month': df2[1], 
    'day': df2[3]
})
df2.set_index('datetime', inplace=True)

df2.drop([0, 1, 2, 3], axis=1, inplace=True)
df2.head()
# Out:
#                   4         5  6         7
# datetime
# 2000-01-06 -0.37285 -0.084006  1  0.382199
# 2000-01-07 -0.41773 -0.162100  1  0.448080
# 2000-01-01 -0.36624 -0.329840  1  0.492872
# 2000-01-02 -0.40185 -0.423020  2  0.583459
# 2000-01-03 -0.12710 -0.364840  2  0.386342

# %%
import matplotlib.pyplot as plt
df2[6].plot()
df['fase'].plot()
ax=plt.gca()
ax.set_xlim(left='20000101',right='20010101')
ax.legend()
